# %% [markdown]
# # PHASE 3

# %%
## question 1
##question 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('imdb_movies.csv1')
df2 = pd.read_csv('imdb_movies.csv2')

# %%
combined_df = df1.merge(df2, on="Movie_name")
print(combined_df.head())
# Out:
#    Sno                                         Movie_name Duration    Year  \
# 0  1.0                                    The Dark Knight  152 min  (2008)
# 1  2.0      The Lord of the Rings: The Return of the King  201 min  (2003)
# 2  3.0                Spider-Man: Across the Spider-Verse  140 min  (2023)
# 3  4.0                                          Inception  148 min  (2010)
# 4  5.0  The Lord of the Rings: The Fellowship of the Ring  178 min  (2001)
#
#    Rating  Metascore    Stars      Votes                         Genre  \
# 0     9.0         84    Nolan  2,744,775          Action, Crime, Drama
# 1     9.0         94    Goyer  1,900,422      Action, Adventure, Drama
# 2     8.9         86  Eckhart    189,449  Animation, Action, Adventure
# 3     8.8         74     info  2,435,767     Action, Adventure, Sci-Fi
# 4     8.8         92      NaN  1,928,809      Action, Adventure, Drama
#
#   Gross_collection
# 0         $534.86M
# 1        1,900,422
# 2         $377.85M
# ...

# %%
print(combined_df)
# Out:
#      Sno                                         Movie_name Duration    Year  \
# 0    1.0                                    The Dark Knight  152 min  (2008)
# 1    2.0      The Lord of the Rings: The Return of the King  201 min  (2003)
# 2    3.0                Spider-Man: Across the Spider-Verse  140 min  (2023)
# 3    4.0                                          Inception  148 min  (2010)
# 4    5.0  The Lord of the Rings: The Fellowship of the Ring  178 min  (2001)
# 5    6.0              The Lord of the Rings: The Two Towers  179 min  (2002)
# 6    7.0                                         The Matrix  136 min  (1999)
# 7    8.0     Star Wars: Episode V - The Empire Strikes Back  124 min  (1980)
# 8    9.0                                    Soorarai Pottru  153 min  (2020)
# 9   10.0                         Terminator 2: Judgment Day  137 min  (1991)
# 10  11.0                 Star Wars: Episode IV - A New Hope  121 min  (1977)
# ...

# %%
print(combined_df.describe())
# Out:
#              Sno     Rating  Metascore
# count  35.000000  35.000000  35.000000
# mean   18.000000   8.514286  78.857143
# std    10.246951   0.215765  10.015115
# min     1.000000   8.300000  62.000000
# 25%     9.500000   8.300000  71.500000
# 50%    18.000000   8.400000  78.000000
# 75%    26.500000   8.650000  85.500000
# max    35.000000   9.000000  98.000000

# %%
print(combined_df.tail())
# Out:
#      Sno        Movie_name Duration    Year  Rating  Metascore  \
# 30  31.0            Dangal  161 min  (2016)     8.3         72
# 31  32.0           Kantara  148 min  (2022)     8.3         69
# 32  33.0  K.G.F: Chapter 2  168 min  (2022)     8.3         62
# 33  34.0            Vikram  175 min  (2022)     8.3         97
# 34  35.0         Shershaah  135 min  (2021)     8.3         72
#
#              Stars    Votes                     Genre Gross_collection
# 30            2008  199,258  Action, Biography, Drama         $190.24M
# 31  $1,006,234,167   96,952  Action, Adventure, Drama        1,196,333
# 32         minutes  141,104      Action, Crime, Drama         $858.37M
# 33  DigitalSDDSDTS   64,850   Action, Crime, Thriller          737,495
# 34               1  125,620  Action, Biography, Drama          $85.16M

# %%
print(combined_df.isnull())
# Out:
#       Sno  Movie_name  Duration   Year  Rating  Metascore  Stars  Votes  \
# 0   False       False     False  False   False      False  False  False
# 1   False       False     False  False   False      False  False  False
# 2   False       False     False  False   False      False  False  False
# 3   False       False     False  False   False      False  False  False
# 4   False       False     False  False   False      False   True  False
# 5   False       False     False  False   False      False   True  False
# 6   False       False     False  False   False      False   True  False
# 7   False       False     False  False   False      False   True  False
# 8   False       False     False  False   False      False  False  False
# 9   False       False     False  False   False      False  False  False
# 10  False       False     False  False   False      False  False  False
# 11  False       False     False  False   False      False  False  False
# ...

# %%
print(combined_df.isnull().sum())
# Out:
# Sno                 0
# Movie_name          0
# Duration            0
# Year                0
# Rating              0
# Metascore           0
# Stars               4
# Votes               0
# Genre               0
# Gross_collection    0
# dtype: int64

# %%
# to clean the data

# %%
combined_df['Stars'] = pd.to_numeric(combined_df['Stars'], errors='coerce')

print(combined_df['Stars'].dtype)

stars_mean = combined_df['Stars'].mean()

combined_df['Stars'].fillna(stars_mean, inplace=True)

print(combined_df.isnull().sum())
# Out:
# float64
# Sno                 0
# Movie_name          0
# Duration            0
# Year                0
# Rating              0
# Metascore           0
# Stars               0
# Votes               0
# Genre               0
# Gross_collection    0
# dtype: int64

# %%
# after i cleaned the stars columns

# %%
print(combined_df.isnull().sum())
# Out:
# Sno                 0
# Movie_name          0
# Duration            0
# Year                0
# Rating              0
# Metascore           0
# Stars               0
# Votes               0
# Genre               0
# Gross_collection    0
# dtype: int64

# %%
print(combined_df.columns)
# Out:
# Index(['Sno', 'Movie_name', 'Duration', 'Year', 'Rating', 'Metascore', 'Stars',
#        'Votes', 'Genre', 'Gross_collection'],
#       dtype='object')

# %%
print(combined_df.columns.tolist())
# Out:
# ['Sno', 'Movie_name', 'Duration', 'Year', 'Rating', 'Metascore', 'Stars', 'Votes', 'Genre', 'Gross_collection']

# %%
print(combined_df.dtypes)
# Out:
# Sno                 float64
# Movie_name           object
# Duration             object
# Year                 object
# Rating              float64
# Metascore             int64
# Stars               float64
# Votes                object
# Genre                object
# Gross_collection     object
# dtype: object

# %%
for i in combined_df.columns:
    print(combined_df[i].value_counts())
    print("/n")
# Out:
# 1.0     1
# 27.0    1
# 21.0    1
# 22.0    1
# 23.0    1
# 24.0    1
# 25.0    1
# 26.0    1
# 28.0    1
# 19.0    1
# 29.0    1
# 30.0    1
# 31.0    1
# 32.0    1
# 33.0    1
# 34.0    1
# 20.0    1
# 18.0    1
# 2.0     1
# 9.0     1
# 3.0     1
# 4.0     1
# 5.0     1
# 6.0     1
# 7.0     1
# 8.0     1
# 10.0    1
# 17.0    1
# 11.0    1
# 12.0    1
# 13.0    1
# 14.0    1
# 15.0    1
# 16.0    1
# 35.0    1
# Name: Sno, dtype: int64
# /n
# The Dark Knight                                      1
# Heat                                                 1
# Oldboy                                               1
# The Dark Knight Rises                                1
# Avengers: Infinity War                               1
# Kaithi                                               1
# Asuran                                               1
# Top Gun: Maverick                                    1
# Star Wars: Episode VI - Return of the Jedi           1
# ...

# %%
sns.heatmap(combined_df.isnull())
# Out:
# <AxesSubplot:>

# %%
## here i took the target_variable  as "votes"  (as menstion below phase 4 question requirement)

# %%
combined_df["Votes"].unique()
# Out:
# array(['2,744,775', '1,900,422', '189,449', '2,435,767', '1,928,809',
#        '1,715,043', '1,972,628', '1,330,781', '120,096', '1,131,913',
#        '1,402,992', '355,184', '62,262', '61,511', '1,547,338',
#        '1,198,341', '1,004,444', '610,909', '1,196,333', '737,495',
#        '602,062', '1,756,238', '1,138,499', '36,838', '31,557', '611,668',
#        '683,805', '1,084,961', '410,746', '336,597', '199,258', '96,952',
#        '141,104', '64,850', '125,620'], dtype=object)

# %%
combined_df["Votes"].nunique()
# Out:
# 35

# %%
sns.scatterplot(x="Movie_name",y='Votes',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Movie_name', ylabel='Votes'>

# %%
sns.scatterplot(x="Duration",y='Votes',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Votes'>

# %%
sns.scatterplot(x="Year",y='Votes',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Votes'>

# %%
sns.scatterplot(x="Rating",y='Votes',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Votes'>

# %%
sns.scatterplot(x="Metascore",y='Votes',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Metascore', ylabel='Votes'>

# %%
sns.scatterplot(x="Stars",y='Votes',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Stars', ylabel='Votes'>

# %%
sns.scatterplot(x="Votes",y='Votes',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Votes'>

# %%
sns.scatterplot(x="Genre",y='Votes',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='Votes'>

# %%
sns.scatterplot(x="Gross_collection",y='Votes',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Gross_collection', ylabel='Votes'>

# %%
## now CORRELATION

# %%
combined_df.corr()
# Out:
#                 Sno        Rating  Metascore         Stars
# Sno        1.000000 -9.431728e-01  -0.397222  6.786695e-03
# Rating    -0.943173  1.000000e+00   0.410657  3.585165e-16
# Metascore -0.397222  4.106574e-01   1.000000  4.889925e-02
# Stars      0.006787  3.585165e-16   0.048899  1.000000e+00

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13,6))
sns.heatmap(combined_df.corr(),annot=True, linewidth=0.8, linecolor="orange",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(combined_df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.show()

# %%
###  SKEW

# %%
combined_df.skew()
# Out:
# Sno          0.000000
# Rating       0.829358
# Metascore    0.346885
# Stars        2.524745
# dtype: float64

# %%
sns.distplot(combined_df["Sno"])
# Out:
# <AxesSubplot:xlabel='Sno', ylabel='Density'>

# %%
sns.distplot(combined_df["Rating"])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(combined_df["Metascore"])
# Out:
# <AxesSubplot:xlabel='Metascore', ylabel='Density'>

# %%
sns.distplot(combined_df["Stars"])
# Out:
# <AxesSubplot:xlabel='Stars', ylabel='Density'>

# %%
### now took TARGET_VARIABLE as "gross collection "    as below phase 4 question required

# %%
combined_df["Gross_collection"].unique()
# Out:
# array(['$534.86M', '1,900,422', '$377.85M', '189,449', '2,435,767',
#        '$292.58M', '1,928,809', '$315.54M', '1,715,043', '$342.55M',
#        '1,972,628', '$171.48M', '1,330,781', '$290.48M', '120,096',
#        '1,131,913', '$204.84M', '1,402,992', '$322.74M', '355,184',
#        '$0.27M', '62,262', '61,511', '1,547,338', '$187.71M', '1,198,341',
#        '$19.50M', '1,004,444', '$248.16M', '610,909', '$190.24M',
#        '1,196,333', '$858.37M', '737,495', '$85.16M'], dtype=object)

# %%
combined_df["Gross_collection"].nunique()
# Out:
# 35

# %%
sns.scatterplot(x="Movie_name",y='Gross_collection',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Movie_name', ylabel='Gross_collection'>

# %%
sns.scatterplot(x="Duration",y='Gross_collection',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Gross_collection'>

# %%
sns.scatterplot(x="Year",y='Gross_collection',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Gross_collection'>

# %%
sns.scatterplot(x="Rating",y='Gross_collection',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Gross_collection'>

# %%
sns.scatterplot(x="Metascore",y='Gross_collection',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Metascore', ylabel='Gross_collection'>

# %%
sns.scatterplot(x="Stars",y='Gross_collection',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Stars', ylabel='Gross_collection'>

# %%
sns.scatterplot(x="Votes",y='Gross_collection',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Gross_collection'>

# %%
sns.scatterplot(x="Genre",y='Gross_collection',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='Gross_collection'>

# %%
sns.scatterplot(x="Gross_collection",y='Gross_collection',data=combined_df)
# Out:
# <AxesSubplot:xlabel='Gross_collection', ylabel='Gross_collection'>

# %%
## with correlation

# %%
combined_df.corr()
# Out:
#                 Sno        Rating  Metascore         Stars
# Sno        1.000000 -9.431728e-01  -0.397222  6.786695e-03
# Rating    -0.943173  1.000000e+00   0.410657  3.585165e-16
# Metascore -0.397222  4.106574e-01   1.000000  4.889925e-02
# Stars      0.006787  3.585165e-16   0.048899  1.000000e+00

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,7))
sns.heatmap(combined_df.corr(),annot=True, linewidth=0.8, linecolor="blue",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,7))
sns.heatmap(round(combined_df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.show()

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sno               35 non-null     float64
#  1   Movie_name        35 non-null     object
#  2   Duration          35 non-null     object
#  3   Year              35 non-null     object
#  4   Rating            35 non-null     float64
#  5   Metascore         35 non-null     int64
#  6   Stars             35 non-null     float64
#  7   Votes             35 non-null     object
#  8   Genre             35 non-null     object
#  9   Gross_collection  35 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
## SKEW

# %%
combined_df.skew()
# Out:
# Sno          0.000000
# Rating       0.829358
# Metascore    0.346885
# Stars        2.524745
# dtype: float64

# %%
sns.distplot(combined_df["Sno"])
# Out:
# <AxesSubplot:xlabel='Sno', ylabel='Density'>

# %%
sns.distplot(combined_df["Rating"])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(combined_df["Metascore"])
# Out:
# <AxesSubplot:xlabel='Metascore', ylabel='Density'>

# %%
sns.distplot(combined_df["Stars"])
# Out:
# <AxesSubplot:xlabel='Stars', ylabel='Density'>

# %%
### Exploring the distribution of 'Rating' using a histogram

# %%
plt.figure(figsize=(10, 7))
sns.histplot(combined_df['Rating'], bins=20, kde=True, color='blue')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Ratings')
plt.show()

# %%
# MY OBSERVATION :: it shows the distribution of movie ratings, overall quality of movies in the datase with histogram.
# i think majority of movies having ratings in certain range

# %%
##  The relationship between 'Rating' and 'Gross_collection' using a scatter plot

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x='Rating', y='Gross_collection', data=combined_df, color='pink')
plt.xlabel('Rating')
plt.ylabel('Gross Collection')
plt.title('Rating vs Gross Collection')
plt.show()

# %%
## MY OBSERVATION ::  scatter plot shows relationship between rating and gross collection
##  meanwhile higher rated movies gives high collections

# %%
## The count of movies in each genre using a bar plot

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='Genre', data=combined_df, order=combined_df['Genre'].value_counts().index, palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Count of Movies in Each Genre')
plt.show()

# %%
## MY OBSERVATION :: bar plot provides distribution of movies of different genre in dataset

# %%
### The average rating of movies per year using a line plot

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Rating', data=combined_df.groupby('Year')['Rating'].mean().reset_index(), marker='o', color='purple')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.title('Average Rating of Movies per Year')
plt.show()

# %%
### MY OBSERVATION :: it shows average rating of different movies

# %%
### Heatmap to see the correlation between numerical columns

# %%
correlation_matrix = combined_df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
### MY OBSERVATION :: Heatmap displays the correlation between numerical columns in the dataset

# %% [markdown]
# # PHASE 4

# %%
## 1) Write the complete Machine learning code to make predictions of votes and gross collection. Use appropriate models on their label basis. Remember you need to make 2 different predictions: vote and gross collection.

# %%
import pandas as pd
import numpy as np
import re


df = pd.read_csv("imdb_movies.csv2")


df['Votes'] = df['Votes'].apply(lambda x: int(re.sub(r'[^\d]', '', str(x))))


def parse_gross(gross):
    if 'M' in gross:
        return float(re.sub(r'[^\d.]', '', gross)) * 1e6
    elif '$' in gross:
        return float(re.sub(r'[^\d.]', '', gross))
    else:
        try:
            return float(re.sub(r'[^\d.]', '', gross))
        except ValueError:
            return np.nan

df['Gross_collection'] = df['Gross_collection'].apply(parse_gross)


votes_gross_df = df[['Votes', 'Gross_collection']]


print(votes_gross_df)
# Out:
#       Votes  Gross_collection
# 0   2744775       534860000.0
# 1   1900422         1900422.0
# 2    189449       377850000.0
# 3   2435767          189449.0
# 4   1928809         2435767.0
# 5   1715043       292580000.0
# 6   1972628         1928809.0
# 7   1330781       315540000.0
# 8    120096         1715043.0
# 9   1131913       342550000.0
# 10  1402992         1972628.0
# 11   355184       171480000.0
# 12    62262         1330781.0
# 13    61511       290480000.0
# 14  1547338          120096.0
# 15  1198341         1131913.0
# 16  1004444       204840000.0
# 17   610909         1402992.0
# 18  1196333       322740000.0
# 19   737495          355184.0
# 20   602062          270000.0
# 21  1756238           62262.0
# 22  1138499           61511.0
# 23    36838         1547338.0
# 24    31557       187710000.0
# 25   611668         1198341.0
# 26   683805        19500000.0
# 27  1084961         1004444.0
# 28   410746       248160000.0
# 29   336597          610909.0
# ...

# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error


df = pd.read_csv("imdb_movies.csv2")

# %%
df['Votes'] = df['Votes'].apply(lambda x: int(re.sub(r'[^\d]', '', str(x))))


def parse_gross(gross):
    if 'M' in gross:
        return float(re.sub(r'[^\d.]', '', gross)) * 1e6
    elif '$' in gross:
        return float(re.sub(r'[^\d.]', '', gross))
    else:
        try:
            return float(re.sub(r'[^\d.]', '', gross))
        except ValueError:
            return np.nan

df['Gross_collection'] = df['Gross_collection'].apply(parse_gross)

# %%
feature_columns = ['Votes']


X = df[feature_columns]
y_votes = df['Votes']
y_gross = df['Gross_collection']


X_train, X_test, y_votes_train, y_votes_test = train_test_split(X, y_votes, test_size=0.2, random_state=42)
_, _, y_gross_train, y_gross_test = train_test_split(X, y_gross, test_size=0.2, random_state=42)


votes_model = LinearRegression()
votes_model.fit(X_train, y_votes_train)


gross_model = RandomForestRegressor(n_estimators=100, random_state=42)
gross_model.fit(X_train, y_gross_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_votes_pred = votes_model.predict(X_test)
y_gross_pred = gross_model.predict(X_test)


mse_votes = mean_squared_error(y_votes_test, y_votes_pred)
mse_gross = mean_squared_error(y_gross_test, y_gross_pred)

print(f"Mean Squared Error for 'Votes' prediction: {mse_votes:.2f}")
print(f"Mean Squared Error for 'Gross_collection' prediction: {mse_gross:.2f}")
# Out:
# Mean Squared Error for 'Votes' prediction: 0.00
# Mean Squared Error for 'Gross_collection' prediction: 34549387847906696.00

# %%
### 2) Apply all the best techniques of scaling, and hyperparameter tuning, and avoid underfitting or overfitting (bias/variance)

# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler


df = pd.read_csv("imdb_movies.csv2")

# %%
df['Votes'] = df['Votes'].apply(lambda x: int(re.sub(r'[^\d]', '', str(x))))

# %%
def parse_gross(gross):
    if 'M' in gross:
        return float(re.sub(r'[^\d.]', '', gross)) * 1e6
    elif '$' in gross:
        return float(re.sub(r'[^\d.]', '', gross))
    else:
        try:
            return float(re.sub(r'[^\d.]', '', gross))
        except ValueError:
            return np.nan

df['Gross_collection'] = df['Gross_collection'].apply(parse_gross)


feature_columns = ['Votes']

# %%
X = df[feature_columns]
y_votes = df['Votes']

# %%
X_train, X_test, y_votes_train, y_votes_test = train_test_split(X, y_votes, test_size=0.2, random_state=42)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search = GridSearchCV(estimator=RandomForestRegressor(random_state=42),
                           param_grid=param_grid,
                           scoring='neg_mean_squared_error',
                           cv=5,
                           verbose=2)

grid_search.fit(X_train_scaled, y_votes_train)


best_params = grid_search.best_params_
print("Best Parameters:", best_params)


best_votes_model = RandomForestRegressor(random_state=42, **best_params)
best_votes_model.fit(X_train_scaled, y_votes_train)


y_votes_pred = best_votes_model.predict(X_test_scaled)


mse_votes = mean_squared_error(y_votes_test, y_votes_pred)
print(f"Mean Squared Error for 'Votes' prediction: {mse_votes:.2f}")


mse_votes = mean_squared_error(y_votes_test, y_votes_pred)
print(f"Mean Squared Error for 'Gross_collection' prediction: {mse_votes:.2f}")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# ...

# %%
## 3)At the end save the best model and convey on which basis you have chosen that model.

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import joblib

# %%
df = pd.read_csv("imdb_movies.csv2")

# %%
df['Votes'] = df['Votes'].apply(lambda x: int(re.sub(r'[^\d]', '', str(x))))

# %%
def parse_gross(gross):
    if 'M' in gross:
        return float(re.sub(r'[^\d.]', '', gross)) * 1e6
    elif '$' in gross:
        return float(re.sub(r'[^\d.]', '', gross))
    else:
        try:
            return float(re.sub(r'[^\d.]', '', gross))
        except ValueError:
            return np.nan

df['Gross_collection'] = df['Gross_collection'].apply(parse_gross)


feature_columns = ['Votes']

# %%
X = df[feature_columns]
y_votes = df['Votes']
y_gross = df['Gross_collection']
X_train, X_test, y_votes_train, y_votes_test, y_gross_train, y_gross_test = train_test_split(X, y_votes, y_gross, test_size=0.2, random_state=42)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(estimator=RandomForestRegressor(random_state=42),
                           param_grid=param_grid,
                           scoring='neg_mean_squared_error',
                           cv=5,
                           verbose=2)

grid_search.fit(X_train_scaled, y_votes_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# ...

# %%
best_params = grid_search.best_params_
print("Best Parameters:", best_params)


best_votes_model = RandomForestRegressor(random_state=42, **best_params)
best_votes_model.fit(X_train_scaled, y_votes_train)


y_votes_pred = best_votes_model.predict(X_test_scaled)


mse_votes = mean_squared_error(y_votes_test, y_votes_pred)
print(f"Mean Squared Error for 'Votes' prediction: {mse_votes:.2f}")


feature_importances_votes = best_votes_model.feature_importances_


gross_model = RandomForestRegressor(random_state=42)
gross_model.fit(X_train_scaled, y_gross_train)


y_gross_pred = gross_model.predict(X_test_scaled)


mse_gross = mean_squared_error(y_gross_test, y_gross_pred)
print(f"Mean Squared Error for 'Gross_collection' prediction: {mse_gross:.2f}")


feature_importances_gross = gross_model.feature_importances_
print("Feature Importances for 'Votes' model:", feature_importances_votes)
print("Feature Importances for 'Gross_collection' model:", feature_importances_gross)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# Mean Squared Error for 'Votes' prediction: 3238528064.56
# Mean Squared Error for 'Gross_collection' prediction: 34549387847906696.00
# Feature Importances for 'Votes' model: [1.]
# Feature Importances for 'Gross_collection' model: [1.]

# %% [markdown]
# ##  MY CONCLUSION :::
# #     Mean Squared Error for 'Votes' prediction: 3238528064.56
# #     Mean Squared Error for 'Gross_collection' prediction: 34549387847906696.00
#
#
# ##  LOWEST MEAN SQUARE ERROR INDICATES BEST PREDICTIVE PERFORMANCE COMPARE TO HIGH MEAN SQUARE ERROR

# %% [markdown]
# ###   HERE "VOTES PREDICTION MODEL HAS LESS MEAN SQUARE ERROR"
#
#
# ## HENCE PROVED THAT VOTES PREDICTION MODEL PERFORMES BEST

# %% [markdown]
# # THANK YOU
